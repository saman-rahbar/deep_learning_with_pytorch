# %% [markdown]
# # Deep Learning Using PyTorch
#
# In this section we will talk about the concept of deep learning, its application, and the use PyTorch package for this purpose.
#
# - Deep Learning Tasks: Vision and language
# - What is Deep Learning?
# - PyTorch packages
# - Projects to be covered

# %% [markdown]
# ## What is Deep Learning?
#
# Deep learning is a machine learning technique which deals with very **high dimensional** data.

# %%
from IPython.display import Image
Image("DL.png")

# %% [markdown]
# **Example**- Using eloborate neural net architecture to learn representation. Learning a cat image from millions of tiny pixels.
#
# **Example-2** - Using complex, high dimensional data, to infere simple, usefull representations/insights.

# %%
Image("NNs.png")

# %%
Image("pytorch_dl.png")
