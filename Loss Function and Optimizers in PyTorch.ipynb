# %% [markdown]
# # Optimizers & Loss Function in PyTorch
#
# In this section we are going to cover the following topics:
#
# - Understanding loss function
# - Taking a look at Cross Entropy Loss

# %% [markdown]
# We start by talking about ** Loss Function **:

# %%
from IPython.display import Image
Image("loss_func.png")

# %% [markdown]
# The purpose of loss function is to know how well or model is performing In terms of predicting the outputs compared to the actuals.

# %% [markdown]
# Pytorch comes with different types of loss functions. You can also write your own loss function if your intended function does not exist in the pytorch defult loss function lists.

# %%
Image("loss_func_pytorch.png")

# %% [markdown]
# **Cross Entropy Loss:**
#
# Tha emodel has to predict the right class from a set of classses

# %%
Image("cross_entropy_loss.png")

# %% [markdown]
# ## Optimizers

# %% [markdown]
# In this section we are going to talk about optimizers in PyTorch. We start by defining what optimizers are.

# %% [markdown]
# - An optimization problem is the problem of finding the best solution from all feasible solutions, given some criteria - Wikipedia
#     - Example: Which line to stand in at the supermarket (*The criteria is to stand as little time as possible in the queue*)

# %% [markdown]
# In the following image you see we caculate the loss functoin in each iteration and then get the gradient of the loss function with respect to the model parameters and the using back-propagation feed it to an optimizer to optimize the loss function and based on that adjust the model parameters.

# %%
Image("optimization.png")
