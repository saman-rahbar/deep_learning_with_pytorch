# %% [markdown]
# # Optimizers & Loss Function in PyTorch
#
# In this section we are going to cover the following topics:
#
# - Understanding loss function
# - Taking a look at Cross Entropy Loss

# %% [markdown]
# We start by talking about ** Loss Function **:

# %%
from IPython.display import Image
Image("loss_func.png")

# %% [markdown]
# The purpose of loss function is to know how well or model is performing In terms of predicting the outputs compared to the actuals.

# %% [markdown]
# Pytorch comes with different types of loss functions. You can also write your own loss function if your intended function does not exist in the pytorch defult loss function lists.

# %%
Image("loss_func_pytorch.png")
